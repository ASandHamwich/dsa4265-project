# %% [markdown]
# # OCBC Scraper

# %%
import requests
from bs4 import BeautifulSoup
import bs4
import csv
import time
import re

import selenium
from selenium import webdriver

# %%
# Links to Scrape

# Savings Accounts
accounts_links = [
    "https://www.ocbc.com/personal-banking/deposits/360-savings-account?pid=Mass:accounts:360Acc:AlwaysOn:Acquisition:Sep:2022:internal:::peb-banner:evergreen:::CFSPersonalise",
    "https://www.ocbc.com/personal-banking/deposits/multi-currency-global-savings-account",
    "https://www.ocbc.com/personal-banking/deposits/bonus-plus-savings-account",
    "https://www.ocbc.com/personal-banking/deposits/multi-currency-usd-current-account",
    "https://www.ocbc.com/personal-banking/deposits/monthly-savings-account",
    "https://www.ocbc.com/personal-banking/deposits/fixed-deposit-account",
    "https://www.ocbc.com/personal-banking/deposits/myown-account",
    "https://www.ocbc.com/personal-banking/deposits/child-development-account",
    "https://www.ocbc.com/personal-banking/deposits/mighty-savers-child-savings-account",
    "https://www.ocbc.com/personal-banking/deposits/passbook-savings-account",
    "https://www.ocbc.com/personal-banking/deposits/statement-passbook-savings-account",
    "https://www.ocbc.com/personal-banking/deposits/basic-current-account",
    "https://www.ocbc.com/personal-banking/investments/online-equities-account",
    "https://www.ocbc.com/personal-banking/investments/unit-trusts/what-are-unit-trusts",
    "https://www.ocbc.com/personal-banking/investments/roboinvest",
    "https://www.ocbc.com/personal-banking/investments/precious-metals-account"
]

card_links = [
    "https://www.ocbc.com/personal-banking/cards/infinity-unlimited-cashback-card",
    "https://www.ocbc.com/personal-banking/cards/rewards-card",
    "https://www.ocbc.com/personal-banking/cards/365-cashback-credit-card",
    "https://www.ocbc.com/personal-banking/cards/90-degrees-travel-credit-card.page",
    "https://www.ocbc.com/personal-banking/cards/bnpl-nxt-card.page",
    "https://www.ocbc.com/premier-banking/our-solutions/cards/premier-visa-infinite",
    "https://www.ocbc.com/personal-banking/cards/great-eastern-cashflo-credit-card.page",
    "https://www.ocbc.com/personal-banking/cards/platinum-rewards-credit-card.page",
    "https://www.ocbc.com/personal-banking/cards/best-denki-rewards-credit-card.page",
    "https://www.ocbc.com/personal-banking/cards/arts-rewards-credit-card.page",
    "https://www.ocbc.com/personal-banking/cards/ocbc-debit-card.page",
]

loan_links = [
    "https://www.ocbc.com/personal-banking/loans/easicredit-flexible-repayment-cash-loan",
    "https://www.ocbc.com/personal-banking/loans/car-loans",
    "https://www.ocbc.com/personal-banking/loans/new-purchase-of-hdb-private-property",
]

insurance_links = [
    "https://www.ocbc.com/personal-banking/insurance/investment-linked-insurance-plan-2",
    "https://www.ocbc.com/personal-banking/insurance/great-careshield",
    "https://www.ocbc.com/personal-banking/insurance/great-term-guard",
    "https://www.ocbc.com/personal-banking/insurance/explorer-travel-insurance"
]

links = accounts_links + card_links + loan_links + insurance_links

# %%
len(links)
# Out:
# 34

# %% [markdown]
# ## Header Chunk

# %%
# Filters
def header_filter(tag: bs4.element.Tag):
    return tag.name == "div" and "com_slider" in tag.get("class", []) and not tag.find("a")

def section_filter(tag: bs4.element.Tag):
    excluded_ids = {
        "section-interestcalculator",
        "section-articles",
        "section-stitch",
        "section-bankingservices",
    }

    return (
        tag.name == "div"
        and tag.get("id", "").startswith("section-")
        and tag.get("id") not in excluded_ids
        and "section" in tag.get("class", [])
    )

# %%
def extract_metadata_tags(url):
    tags = []
    if "insurance" in url:
        tags.append("insurance")
    if "loan" in url or "loans" in url:
        tags.append("loans")
    if "credit-card" in url or "cards" in url:
        tags.append("credit cards")
    if "save" in url or "deposit" in url:
        tags.append("savings")
    if "invest" in url:
        tags.append("investments")
    if "wealth" in url:
        tags.append("wealth management")
    return ", ".join(tags) if tags else "general"

# %%
def scraper(links):
    # Initialise Selenium
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    driver = webdriver.Chrome(options=options)
    
    rows = []

    for url in links:
        print(f"Current URL: {url}")

        driver.get(url)
        time.sleep(5)

        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")


        main = soup.find("section", id="main-wrapper")
        if not main:
            print("❌ Could not find main content area with id='main-wrapper'")
            return

        else:
            print("✅ Found main content section.")

    
        # Scrape header content
        output = main.find_all(header_filter)
        print(f"Found {len(output)} matching 'com_slider' sections.")

        h1 = main.find("h1")
        h2 = main.find("h2")
        title = h1.get_text(strip=True) if h1 else ""
        subtitle = h2.get_text(strip=True) if h2 else ""
        metadata = extract_metadata_tags(url)

        # Parse each 'com_slider' block
        for section in output:
            current_subheader = ""

            for tag in section.descendants:
                if isinstance(tag, bs4.element.Tag):
                    if tag.name == "b":
                        current_subheader = tag.get_text(strip=True)
                    elif tag.name == "span":
                        text = tag.get_text(strip=True)
                        if text:
                            rows.append({
                                "url": url,
                                "title": title,
                                "subtitle": subtitle,
                                "subheader": current_subheader,
                                "text": text,
                                "tag": metadata
                            })

        # Scrape sectional content

        candidates = soup.find_all("div", id=lambda x: x and x.startswith("section-"))
        print(f"Found {len(candidates)} divs with id starting 'section-':")
        for c in candidates:
            print(f"  -> id: {c['id']}, class: {c.get('class', [])}")

        sections = main.find_all(section_filter, recursive=True)
        print(f"✅ Found {len(sections)} structured section divs.")

        for section in sections:
            print(f"🔍 Scraping section: {section.get('id', 'No ID')}")

            h1 = main.find("h1")
            h2 = main.find("h2")
            title = h1.get_text(strip=True) if h1 else ""
            subtitle = h2.get_text(strip=True) if h2 else ""
            metadata = extract_metadata_tags(url)


            current_h3 = ""
            current_b = ""
            current_subcat = ""

            # Fallback subheader from section id
            section_id = section.get("id", "")
            fallback_subheader = section_id.replace("section-", "").replace("-", " ").title() if section_id else ""

            for tag in section.find_all(["h1", "h2", "h3", "b", "p", "li", "div"]):
                text = tag.get_text(strip=True)
                if not text:
                    continue

                tag_name = tag.name.lower()
                classes = tag.get("class", [])

                if tag_name == "h3":
                    current_h3 = text
                elif tag_name == "b":
                    current_b = text
                elif tag_name == "div" and "subcategory" in classes:
                    current_subcat = text
                elif tag_name in ["p", "li"]:
                    # Subheader priority: b > subcategory > h3 > section fallback
                    subheader = current_b or current_subcat or current_h3 or fallback_subheader
                    rows.append({
                        "url": url,
                        "title": title,
                        "subtitle": subtitle,
                        "subheader": subheader,
                        "text": text,
                        "tag": metadata
                    })

    # Write to CSV
    print("Writing to CSV...")
    fieldnames = ["url", "title", "subtitle", "subheader", "text", "tag"]
    try:
        with open("ocbc_data.csv", "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=fieldnames)
            writer.writeheader()
            for row in rows:
                writer.writerow(row)
        
        print("Data written to ocbc_data.csv.")
    except Exception as e:
        print(f"Error writing to CSV: {e}")
        return

# %%
scraper(links)
# Out:
# Current URL: https://www.ocbc.com/personal-banking/deposits/360-savings-account?pid=Mass:accounts:360Acc:AlwaysOn:Acquisition:Sep:2022:internal:::peb-banner:evergreen:::CFSPersonalise
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 11 divs with id starting 'section-':
#   -> id: section-importantnotice, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-howitworks, class: ['section', 'section-both']
#   -> id: section-interestcalculator, class: ['section', 'section-both', 'bg-grey', 'noprint']
#   -> id: section-trackyourbonuseligibilityeasily, class: ['section', 'section-both']
#   -> id: section-stitch, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-moneylock, class: ['section', 'section-both']
#   -> id: section-articles, class: ['section', 'section-both', 'bg-grey', 'noprint']
#   -> id: section-beforeyouapply, class: ['section', 'section-both']
#   -> id: section-bankingservices, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-waystoapply, class: ['section', 'section-both']
#   -> id: section-faqs, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 7 structured section divs.
# 🔍 Scraping section: section-importantnotice
# 🔍 Scraping section: section-howitworks
# 🔍 Scraping section: section-trackyourbonuseligibilityeasily
# 🔍 Scraping section: section-moneylock
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/deposits/multi-currency-global-savings-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 6 divs with id starting 'section-':
#   -> id: section-benefits, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-rates, class: ['section', 'section-both']
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-bankingservices, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section', 'section-top', 'bg-grey']
#   -> id: section-faqs, class: ['section', 'section-both']
# ✅ Found 5 structured section divs.
# 🔍 Scraping section: section-benefits
# 🔍 Scraping section: section-rates
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/deposits/bonus-plus-savings-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 6 divs with id starting 'section-':
#   -> id: section-howitworks, class: ['section', 'section-both']
#   -> id: section-stitch, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-both']
#   -> id: section-bankingservices, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-waystoapply, class: ['section', 'section-both']
#   -> id: section-faqs, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 4 structured section divs.
# 🔍 Scraping section: section-howitworks
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/deposits/multi-currency-usd-current-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 3 divs with id starting 'section-':
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey', 'iw_off']
#   -> id: section-bankingservices, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 2 structured section divs.
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# Current URL: https://www.ocbc.com/personal-banking/deposits/monthly-savings-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 5 divs with id starting 'section-':
#   -> id: section-how-it-works, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-before-you-apply, class: ['section', 'section-both']
#   -> id: section-banking-services, class: ['section', 'section-top', 'bg-grey']
#   -> id: section-waystoapply, class: ['section', 'section-bottom']
#   -> id: section-faqs, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 5 structured section divs.
# 🔍 Scraping section: section-how-it-works
# 🔍 Scraping section: section-before-you-apply
# 🔍 Scraping section: section-banking-services
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/deposits/fixed-deposit-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 9 divs with id starting 'section-':
#   -> id: section-rates, class: ['section', 'section-both', 'iw_off', 'bg-grey']
#   -> id: section-placetd, class: ['section', 'section-both']
#   -> id: section-applydb, class: ['section', 'section-both', 'bg-grey', 'd-none', 'soft']
#   -> id: section-applydb, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-moneylock, class: ['section', 'section-both']
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-bankingservices, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-faqs, class: ['section', 'section-both']
# ✅ Found 8 structured section divs.
# 🔍 Scraping section: section-rates
# 🔍 Scraping section: section-placetd
# 🔍 Scraping section: section-applydb
# 🔍 Scraping section: section-applydb
# 🔍 Scraping section: section-moneylock
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/deposits/myown-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 5 divs with id starting 'section-':
#   -> id: section-intro, class: ['section', 'section-both']
#   -> id: section-hear, class: ['section', 'section-bottom', 'px-2', 'overflow-hidden']
#   -> id: section-tendesigns, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-faqs, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 5 structured section divs.
# 🔍 Scraping section: section-intro
# 🔍 Scraping section: section-hear
# 🔍 Scraping section: section-tendesigns
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/deposits/child-development-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 13 divs with id starting 'section-':
#   -> id: section-intro, class: ['section', 'section-both']
#   -> id: section-benefits, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-howitworks, class: ['section', 'section-top']
#   -> id: section-stitch, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-limited, class: ['section', 'section-both', 'd-none-soft']
#   -> id: section-newparents, class: ['section', 'section-both']
#   -> id: section-highlights, class: ['section', 'section-both']
#   -> id: section-howtoapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-waystoapply, class: ['module', 'container', 'bp-width-med3', 'animate']
#   -> id: section-additionalsupport, class: ['section', 'section-both']
#   -> id: section-faqs, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 11 structured section divs.
# 🔍 Scraping section: section-intro
# 🔍 Scraping section: section-benefits
# 🔍 Scraping section: section-howitworks
# 🔍 Scraping section: section-limited
# 🔍 Scraping section: section-newparents
# 🔍 Scraping section: section-highlights
# 🔍 Scraping section: section-howtoapply
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-additionalsupport
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/deposits/mighty-savers-child-savings-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 7 divs with id starting 'section-':
#   -> id: section-intro, class: ['section', 'section-bottom']
#   -> id: section-howitworks, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-privileges, class: ['section', 'section-both']
#   -> id: section-beforeyouapply, class: ['section', 'section-both']
#   -> id: section-bankingservices, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-howtoapply, class: ['section', 'section-both']
#   -> id: section-faqs, class: ['module', 'container', 'bp-width-med3', 'animate']
# ✅ Found 5 structured section divs.
# 🔍 Scraping section: section-intro
# 🔍 Scraping section: section-howitworks
# 🔍 Scraping section: section-privileges
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-howtoapply
# Current URL: https://www.ocbc.com/personal-banking/deposits/passbook-savings-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 4 divs with id starting 'section-':
#   -> id: section-rates, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-bankingservices, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 3 structured section divs.
# 🔍 Scraping section: section-rates
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# Current URL: https://www.ocbc.com/personal-banking/deposits/statement-passbook-savings-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 4 divs with id starting 'section-':
#   -> id: section-rates, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-bankingservices, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 3 structured section divs.
# 🔍 Scraping section: section-rates
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# Current URL: https://www.ocbc.com/personal-banking/deposits/basic-current-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 3 divs with id starting 'section-':
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey', 'iw_off']
#   -> id: section-bankingservices, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section', 'section-top']
# ✅ Found 2 structured section divs.
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# Current URL: https://www.ocbc.com/personal-banking/investments/online-equities-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 12 divs with id starting 'section-':
#   -> id: section-meetneeds, class: ['section', 'section-both', 'overflow-hidden']
#   -> id: section-award, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-waystopay, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-feescharges, class: ['section', 'section-both']
#   -> id: section-glimpseplatform, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-getstarted, class: ['section', 'section-both', 'overflow-hidden']
#   -> id: section-complexproducts, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-exclusive, class: ['section', 'section-both', 'd-none']
#   -> id: section-topstockideas, class: ['section', 'section-both']
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-waystoapply, class: ['section', 'section-both']
#   -> id: section-faqs, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 12 structured section divs.
# 🔍 Scraping section: section-meetneeds
# 🔍 Scraping section: section-award
# 🔍 Scraping section: section-waystopay
# 🔍 Scraping section: section-feescharges
# 🔍 Scraping section: section-glimpseplatform
# 🔍 Scraping section: section-getstarted
# 🔍 Scraping section: section-complexproducts
# 🔍 Scraping section: section-exclusive
# 🔍 Scraping section: section-topstockideas
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/investments/unit-trusts/what-are-unit-trusts
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 8 divs with id starting 'section-':
#   -> id: section-about, class: ['section', 'section-both']
#   -> id: section-ourtopfunds, class: ['section', 'section-both', 'iw_off', 'bg-grey']
#   -> id: section-featured, class: ['section', 'section-both', 'iw_off']
#   -> id: section-featuredfund, class: ['section', 'section-both', 'iw_off', 'd-none-soft']
#   -> id: section-feescharges, class: ['section', 'section-both']
#   -> id: section-articles, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section']
# ✅ Found 7 structured section divs.
# 🔍 Scraping section: section-about
# 🔍 Scraping section: section-ourtopfunds
# 🔍 Scraping section: section-featured
# 🔍 Scraping section: section-featuredfund
# 🔍 Scraping section: section-feescharges
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# Current URL: https://www.ocbc.com/personal-banking/investments/roboinvest
# ✅ Found main content section.
# Found 0 matching 'com_slider' sections.
# Found 11 divs with id starting 'section-':
#   -> id: section-about, class: ['section', 'section-both']
#   -> id: section-awards, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-topperforming, class: ['section', 'section-both', 'iw_off']
#   -> id: section-mostpopular, class: ['section', 'section-both', 'iw_off', 'bg-grey']
#   -> id: section-roboinvestreferral, class: ['section', 'section-both']
#   -> id: section-featuredportfolio, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-feescharges, class: ['section', 'section-both']
#   -> id: section-articles, class: ['section', 'section-bottom', 'bg-grey']
#   -> id: section-beforeyouinvest, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section', 'section-top', 'bg-grey']
#   -> id: section-additionalinformation, class: ['section', 'section-both']
# ✅ Found 10 structured section divs.
# 🔍 Scraping section: section-about
# 🔍 Scraping section: section-awards
# 🔍 Scraping section: section-topperforming
# 🔍 Scraping section: section-mostpopular
# 🔍 Scraping section: section-roboinvestreferral
# 🔍 Scraping section: section-featuredportfolio
# 🔍 Scraping section: section-feescharges
# 🔍 Scraping section: section-beforeyouinvest
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-additionalinformation
# Current URL: https://www.ocbc.com/personal-banking/investments/precious-metals-account
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 8 divs with id starting 'section-':
#   -> id: section-featuresbenefits, class: ['section', 'section-both', 'iw_off']
#   -> id: section-diversify, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-howitworks, class: ['section', 'section-both']
#   -> id: section-howitworks, class: ['module', 'container', 'bp-width-med3']
#   -> id: section-articles, class: ['section', 'section-both', 'bg-grey', 'noprint']
#   -> id: section-beforeyouinvest, class: ['section', 'section-both']
#   -> id: section-getstarted, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-additionalinformation, class: ['section', 'section-both']
# ✅ Found 6 structured section divs.
# 🔍 Scraping section: section-featuresbenefits
# 🔍 Scraping section: section-diversify
# 🔍 Scraping section: section-howitworks
# 🔍 Scraping section: section-beforeyouinvest
# 🔍 Scraping section: section-getstarted
# 🔍 Scraping section: section-additionalinformation
# Current URL: https://www.ocbc.com/personal-banking/cards/infinity-unlimited-cashback-card
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 6 divs with id starting 'section-':
#   -> id: section-benefits, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-mastercard, class: ['section', 'section-both']
#   -> id: section-infinityx360, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-both']
#   -> id: section-readytoapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-faqs, class: ['section']
# ✅ Found 6 structured section divs.
# 🔍 Scraping section: section-benefits
# 🔍 Scraping section: section-mastercard
# 🔍 Scraping section: section-infinityx360
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-readytoapply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/cards/rewards-card
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 12 divs with id starting 'section-':
#   -> id: section-intro, class: ['section']
#   -> id: section-exclusiveoffer, class: ['section', 'section-both']
#   -> id: section-benefits, class: ['section', 'section-both', 'iw_off', 'bg-grey']
#   -> id: section-more, class: ['section', 'section-both']
#   -> id: section-merchants, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-promo, class: ['section', 'section-top']
#   -> id: section-mastercard, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-360, class: ['section', 'section-both']
#   -> id: section-other, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-faqs, class: ['section', 'section-both']
# ✅ Found 12 structured section divs.
# 🔍 Scraping section: section-intro
# 🔍 Scraping section: section-exclusiveoffer
# 🔍 Scraping section: section-benefits
# 🔍 Scraping section: section-more
# 🔍 Scraping section: section-merchants
# 🔍 Scraping section: section-promo
# 🔍 Scraping section: section-mastercard
# 🔍 Scraping section: section-360
# 🔍 Scraping section: section-other
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/cards/365-cashback-credit-card
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 6 divs with id starting 'section-':
#   -> id: section-benefits, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-360x365cc, class: ['section', 'section-both']
#   -> id: section-promo, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-top']
#   -> id: section-waystoapply, class: ['section', 'section-bottom', 'bg-grey']
#   -> id: section-faqs, class: ['section', 'section-both']
# ✅ Found 6 structured section divs.
# 🔍 Scraping section: section-benefits
# 🔍 Scraping section: section-360x365cc
# 🔍 Scraping section: section-promo
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/cards/90-degrees-travel-credit-card.page
# ✅ Found main content section.
# Found 2 matching 'com_slider' sections.
# Found 16 divs with id starting 'section-':
#   -> id: section-traveldollar, class: ['section', 'section-both', 'iw_off']
#   -> id: section-cashrebatesmc, class: ['section', 'section-both', 'iw_off', 'bg-grey']
#   -> id: section-maximize, class: ['section', 'section-both', 'iw_off']
#   -> id: section-90nvisa-exclusivepromo, class: ['section', 'section-both', 'unhidegetgo1', 'd-none-soft']
#   -> id: section-getgo1-dragonpass-steps, class: ['section', 'section-both', 'iw_off', 'unhidegetgo1', 'd-none-soft']
#   -> id: section-privileges, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-privileges-getgo1, class: ['section', 'section-both', 'unhidegetgo1', 'd-none-soft']
#   -> id: section-latest-getgo1, class: ['section', 'section-both', 'iw_off', 'bg-grey', 'unhidegetgo1', 'd-none-soft']
#   -> id: section-latest, class: ['section', 'section-both', 'iw_off']
#   -> id: section-getgo1beforeyouapply, class: ['section', 'section-both', 'unhidegetgo1', 'd-none-soft']
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-getgo1readytoapply, class: ['section', 'section-both', 'bg-grey', 'unhidegetgo1', 'd-none-soft']
#   -> id: section-readytoapply, class: ['section', 'section-both']
#   -> id: section-readytoapply, class: ['module', 'container', 'bp-width-med3', 'animate', 'cta__basic--noshadow']
#   -> id: section-faqs-getgo1, class: ['section', 'section-both', 'unhidegetgo1', 'd-none-soft']
#   -> id: section-faqs, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 15 structured section divs.
# 🔍 Scraping section: section-traveldollar
# 🔍 Scraping section: section-cashrebatesmc
# 🔍 Scraping section: section-maximize
# 🔍 Scraping section: section-90nvisa-exclusivepromo
# 🔍 Scraping section: section-getgo1-dragonpass-steps
# 🔍 Scraping section: section-privileges
# 🔍 Scraping section: section-privileges-getgo1
# 🔍 Scraping section: section-latest-getgo1
# 🔍 Scraping section: section-latest
# 🔍 Scraping section: section-getgo1beforeyouapply
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-getgo1readytoapply
# 🔍 Scraping section: section-readytoapply
# 🔍 Scraping section: section-faqs-getgo1
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/cards/bnpl-nxt-card.page
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 8 divs with id starting 'section-':
#   -> id: section-benefits, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-50cboffer, class: ['section', 'section-both', 'unhide50cboffer', 'd-none-soft']
#   -> id: section-360xcardspromo, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-gettingstarted, class: ['section', 'section-both']
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-apply, class: ['section', 'section-bottom', 'bg-grey', 'unhide50cboffer', 'd-none-soft']
#   -> id: section-faqs, class: ['section', 'section-both']
#   -> id: section-faqs, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 8 structured section divs.
# 🔍 Scraping section: section-benefits
# 🔍 Scraping section: section-50cboffer
# 🔍 Scraping section: section-360xcardspromo
# 🔍 Scraping section: section-gettingstarted
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-apply
# 🔍 Scraping section: section-faqs
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/premier-banking/our-solutions/cards/premier-visa-infinite
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 0 divs with id starting 'section-':
# ✅ Found 0 structured section divs.
# Current URL: https://www.ocbc.com/personal-banking/cards/great-eastern-cashflo-credit-card.page
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 5 divs with id starting 'section-':
#   -> id: section-benefits, class: ['section', 'section-both', 'iw_off', 'bg-grey']
#   -> id: section-getting-started, class: ['section', 'section-both']
#   -> id: section-before-you-apply, class: ['section', 'section-top', 'bg-grey']
#   -> id: section-ready-to-apply, class: ['section', 'section-bottom']
#   -> id: section-faqs, class: ['section', 'section-top', 'bg-grey']
# ✅ Found 5 structured section divs.
# 🔍 Scraping section: section-benefits
# 🔍 Scraping section: section-getting-started
# 🔍 Scraping section: section-before-you-apply
# 🔍 Scraping section: section-ready-to-apply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/cards/platinum-rewards-credit-card.page
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 5 divs with id starting 'section-':
#   -> id: section-benefits, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-features, class: ['section', 'section-both']
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-waystoapply, class: ['section', 'section-both']
#   -> id: section-faqs, class: ['section', 'section-top', 'bg-grey']
# ✅ Found 5 structured section divs.
# 🔍 Scraping section: section-benefits
# 🔍 Scraping section: section-features
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/cards/best-denki-rewards-credit-card.page
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 3 divs with id starting 'section-':
#   -> id: section-benefits, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-before-you-apply, class: ['section', 'section-top']
#   -> id: section-waystoapply, class: ['section', 'bg-grey']
# ✅ Found 3 structured section divs.
# 🔍 Scraping section: section-benefits
# 🔍 Scraping section: section-before-you-apply
# 🔍 Scraping section: section-waystoapply
# Current URL: https://www.ocbc.com/personal-banking/cards/arts-rewards-credit-card.page
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 3 divs with id starting 'section-':
#   -> id: section-benefits, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 3 structured section divs.
# 🔍 Scraping section: section-benefits
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-waystoapply
# Current URL: https://www.ocbc.com/personal-banking/cards/ocbc-debit-card.page
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 7 divs with id starting 'section-':
#   -> id: section-earnunlimited, class: ['section', 'section-both']
#   -> id: section-domore, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-getacard, class: ['section', 'section-both']
#   -> id: section-draw, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-top']
#   -> id: section-cta, class: ['section', 'section-bottom']
#   -> id: section-faqs, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 7 structured section divs.
# 🔍 Scraping section: section-earnunlimited
# 🔍 Scraping section: section-domore
# 🔍 Scraping section: section-getacard
# 🔍 Scraping section: section-draw
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-cta
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/loans/easicredit-flexible-repayment-cash-loan
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 9 divs with id starting 'section-':
#   -> id: section-benefits, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-interest-rates, class: ['section', 'section-both']
#   -> id: section-feescharges, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-permcli, class: ['section', 'iw_off']
#   -> id: section-promotion, class: ['section', 'section-both', 'bg-grey', 'd-none-soft']
#   -> id: section-easicredit, class: ['section', 'section-both', 'bg-grey', 'noprint']
#   -> id: section-before-you-apply, class: ['section', 'section-top']
#   -> id: section-waystoapply, class: []
#   -> id: section-faqs, class: ['section', 'section-both']
# ✅ Found 8 structured section divs.
# 🔍 Scraping section: section-benefits
# 🔍 Scraping section: section-interest-rates
# 🔍 Scraping section: section-feescharges
# 🔍 Scraping section: section-permcli
# 🔍 Scraping section: section-promotion
# 🔍 Scraping section: section-easicredit
# 🔍 Scraping section: section-before-you-apply
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/loans/car-loans
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 8 divs with id starting 'section-':
#   -> id: section-awards, class: ['section']
#   -> id: section-applyforanocbccarloan, class: ['section', 'section-both', 'bg-grey', 'overflow-hidden']
#   -> id: section-ecocare, class: ['container', 'bp-width-med3', 'module', 'animate', 'anim-content']
#   -> id: section-interestrates, class: ['section', 'section-both']
#   -> id: section-carloansrepaymentmethods, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-top']
#   -> id: section-cta, class: ['section']
#   -> id: section-faq, class: ['section', 'section-both', 'bg-grey']
# ✅ Found 7 structured section divs.
# 🔍 Scraping section: section-awards
# 🔍 Scraping section: section-applyforanocbccarloan
# 🔍 Scraping section: section-interestrates
# 🔍 Scraping section: section-carloansrepaymentmethods
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-cta
# 🔍 Scraping section: section-faq
# Current URL: https://www.ocbc.com/personal-banking/loans/new-purchase-of-hdb-private-property
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 12 divs with id starting 'section-':
#   -> id: section-awards, class: ['section', 'section-bottom', 'bg-grey']
#   -> id: section-features, class: ['section', 'section-both']
#   -> id: section-ecocare, class: ['section', 'section-top', 'd-none-soft']
#   -> id: section-partners, class: ['section', 'bg-grey']
#   -> id: section-home-loan-packages, class: ['section', 'section-both']
#   -> id: section-process, class: ['section', 'section-both', 'bg-grey', 'overflow-hidden']
#   -> id: section-loan-calculator, class: ['section', 'section-both']
#   -> id: section-hdbipa, class: ['section', 'section-both']
#   -> id: section-manageloan, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-before-you-apply, class: ['section', 'section-both']
#   -> id: section-waystoapply, class: ['section', 'section-bottom', 'bg-grey']
#   -> id: section-faq, class: ['section', 'section-both']
# ✅ Found 12 structured section divs.
# 🔍 Scraping section: section-awards
# 🔍 Scraping section: section-features
# 🔍 Scraping section: section-ecocare
# 🔍 Scraping section: section-partners
# 🔍 Scraping section: section-home-loan-packages
# 🔍 Scraping section: section-process
# 🔍 Scraping section: section-loan-calculator
# 🔍 Scraping section: section-hdbipa
# 🔍 Scraping section: section-manageloan
# 🔍 Scraping section: section-before-you-apply
# 🔍 Scraping section: section-waystoapply
# 🔍 Scraping section: section-faq
# Current URL: https://www.ocbc.com/personal-banking/insurance/investment-linked-insurance-plan-2
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 5 divs with id starting 'section-':
#   -> id: section-featuresandbenefits, class: ['section', 'section-both']
#   -> id: section-howitworks, class: ['section', 'section-top', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-both']
#   -> id: section-appointment, class: ['section', 'section-both']
#   -> id: section-faqs, class: ['section', 'section-both']
# ✅ Found 5 structured section divs.
# 🔍 Scraping section: section-featuresandbenefits
# 🔍 Scraping section: section-howitworks
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-appointment
# 🔍 Scraping section: section-faqs
# Current URL: https://www.ocbc.com/personal-banking/insurance/great-careshield
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 10 divs with id starting 'section-':
#   -> id: section-featuresandbenefits, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-mohliner, class: ['section', 'section-both']
#   -> id: section-howitworks, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-letusguideyou, class: ['section', 'section-both']
#   -> id: section-promotion, class: ['section', 'section-both', 'bg-grey', 'noprint']
#   -> id: section-promotion, class: ['module', 'promotion__section', 'promotion__section-bg-green', 'promoblock__pt-none']
#   -> id: section-articles, class: ['section', 'section-both', 'noprint']
#   -> id: section-articles, class: ['com__lifegoals-articles-and-guides']
#   -> id: section-beforeyouapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-viewpricing, class: ['section', 'section-both']
# ✅ Found 7 structured section divs.
# 🔍 Scraping section: section-featuresandbenefits
# 🔍 Scraping section: section-mohliner
# 🔍 Scraping section: section-howitworks
# 🔍 Scraping section: section-letusguideyou
# 🔍 Scraping section: section-promotion
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-viewpricing
# Current URL: https://www.ocbc.com/personal-banking/insurance/great-term-guard
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 3 divs with id starting 'section-':
#   -> id: section-best, class: ['section', 'bg-grey']
#   -> id: section-letusguideyou, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-articles, class: ['section', 'noprint']
# ✅ Found 2 structured section divs.
# 🔍 Scraping section: section-best
# 🔍 Scraping section: section-letusguideyou
# Current URL: https://www.ocbc.com/personal-banking/insurance/explorer-travel-insurance
# ✅ Found main content section.
# Found 1 matching 'com_slider' sections.
# Found 11 divs with id starting 'section-':
#   -> id: section-greateastern, class: ['section', 'section-both']
#   -> id: section-why, class: ['section', 'section-both']
#   -> id: section-coverage, class: ['section', 'bg-grey']
#   -> id: section-howtoapply, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-apply-via-our-award-winning-experience, class: ['module', 'container', 'bp-width-med3']
#   -> id: section-coverageplans, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-emergency, class: ['section', 'section-both']
#   -> id: section-howtoclaim, class: ['section', 'section-both', 'bg-grey']
#   -> id: section-beforeyouapply, class: ['section', 'section-both']
#   -> id: section-viewpricing, class: ['section', 'bg-grey']
#   -> id: section-faqs, class: ['section', 'section-both']
# ✅ Found 10 structured section divs.
# 🔍 Scraping section: section-greateastern
# 🔍 Scraping section: section-why
# 🔍 Scraping section: section-coverage
# 🔍 Scraping section: section-howtoapply
# 🔍 Scraping section: section-coverageplans
# 🔍 Scraping section: section-emergency
# 🔍 Scraping section: section-howtoclaim
# 🔍 Scraping section: section-beforeyouapply
# 🔍 Scraping section: section-viewpricing
# 🔍 Scraping section: section-faqs
# Writing to CSV...
# Data written to ocbc_data.csv.
