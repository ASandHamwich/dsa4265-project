# %% [markdown]
# # Citibank Scraper

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# %%
# Function to extract tables from a page
def extract_tables(soup):
    tables = []
    for table in soup.find_all("table"):
        rows = []
        for tr in table.find_all("tr"):
            cols = [td.get_text(strip=True) for td in tr.find_all(["td", "th"])]
            if cols:
                rows.append(" | ".join(cols))
        if rows:
            tables.append(" / ".join(rows))
    return " || ".join(tables)

# Step 1: Download and parse the sitemap
sitemap_url = "https://www.citibank.com.sg/sitemap.xml"
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(sitemap_url, headers=headers)
soup = BeautifulSoup(response.content, "xml")

# Step 2: Extract all URLs from the sitemap
urls = [loc.text for loc in soup.find_all("loc")]

# Step 3: Filter personal banking URLs
personal_banking_keywords = [
    "/personal-banking/",
    "/credit-cards/",
    "/loans/",
    "/investments/",
    "/insurance/"
]
personal_urls = [url for url in urls if any(keyword in url for keyword in personal_banking_keywords)]

print(f"Found {len(personal_urls)} personal banking pages.")

# Step 4: Scrape each personal banking page
with open("citibank_personal_banking_data.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["URL", "Title", "H1", "Subheadings", "Paragraphs", "Bullet Points", "Tables"])

    for i, url in enumerate(personal_urls):
        print(f"[{i+1}/{len(personal_urls)}] Scraping: {url}")
        try:
            page = requests.get(url, headers=headers, timeout=10)
            page_soup = BeautifulSoup(page.text, "html.parser")

            # Extract title
            title = page_soup.find("title").text.strip() if page_soup.find("title") else ""

            # Extract h1
            h1 = page_soup.find("h1").text.strip() if page_soup.find("h1") else ""

            # Extract all h2 subheadings
            h2s = [h2.text.strip() for h2 in page_soup.find_all("h2")]
            subheadings = " | ".join(h2s)

            # Extract all paragraphs
            paragraphs = [p.text.strip() for p in page_soup.find_all("p") if p.text.strip()]
            paragraph_text = " | ".join(paragraphs)

            # Extract all bullet points
            bullets = [li.text.strip() for li in page_soup.find_all("li") if li.text.strip()]
            bullet_text = " | ".join(bullets)

            # Extract tables
            tables = extract_tables(page_soup)

            # Write to CSV
            writer.writerow([url, title, h1, subheadings, paragraph_text, bullet_text, tables])

        except Exception as e:
            print(f"Failed to scrape {url}: {e}")
            writer.writerow([url, "ERROR", "", "", "", "", str(e)])

        time.sleep(1)

print("Scraping complete. Data saved to 'citibank_personal_banking_data.csv'.")
# Out:
# Found 105 personal banking pages.
# [1/105] Scraping: https://www.citibank.com.sg/credit-cards/
# [2/105] Scraping: https://www.citibank.com.sg/gcb/loans/home.htm
# [3/105] Scraping: https://www.citibank.com.sg/personal-banking/
# [4/105] Scraping: https://www.citibank.com.sg/gcb/insurance/creditInsure.htm
# [5/105] Scraping: https://www.citibank.com.sg/gcb/insurance/creditinsure_insurance.htm
# [6/105] Scraping: https://www.citibank.com.sg/gcb/insurance/health-insurance.htm
# [7/105] Scraping: https://www.citibank.com.sg/gcb/insurance/in_ap_cds.htm
# [8/105] Scraping: https://www.citibank.com.sg/gcb/insurance/insurance-products.htm
# [9/105] Scraping: https://www.citibank.com.sg/gcb/insurance/travel-insurance.htm
# [10/105] Scraping: https://www.citibank.com.sg/loans/mortgage/learn-and-help
# [11/105] Scraping: https://www.citibank.com.sg/loans/mortgage/manage-mortgage
# [12/105] Scraping: https://www.citibank.com.sg/loans/mortgage/mortgage-calculator
# [13/105] Scraping: https://www.citibank.com.sg/gcb/loans/debt-consolidation/debt-consolidation.htm
# [14/105] Scraping: https://www.citibank.com.sg/credit-cards/privileges-programs/credit-card-rewards-redemption/
# [15/105] Scraping: https://www.citibank.com.sg/loans/mortgage/learn-and-help/mortgage-tips-and-guide
# [16/105] Scraping: https://www1.citibank.com.sg/loans/paylite
# [17/105] Scraping: https://www.citibank.com.sg/loans/mortgage/learn-and-help/mortgage-articles
# [18/105] Scraping: https://www.citibank.com.sg/credit-cards/rewards/prestige-credit-card/
# [19/105] Scraping: https://www.citibank.com.sg/investments/investment-products/unit-trusts/
# [20/105] Scraping: https://www.citibank.com.sg/personal-banking/wealth-journey/
# [21/105] Scraping: https://www.citibank.com.sg/credit-cards/rewards/citi-rewards-card/
# [22/105] Scraping: https://www.citibank.com.sg/credit-cards/other-services/ezpay/
# [23/105] Scraping: https://www.citibank.com.sg/credit-cards/student/citi-clear-card/
# [24/105] Scraping: https://www1.citibank.com.sg/loans/flexibill
# [25/105] Scraping: https://www1.citibank.com.sg/personal-banking/online-services/mobile-banking/citi-mobile-app
# [26/105] Scraping: https://www.citibank.com.sg/credit-cards/cashback/cashback-plus-card/
# [27/105] Scraping: https://www1.citibank.com.sg/personal-banking/other-services/bank-branches
# [28/105] Scraping: https://www.citibank.com.sg/credit-cards/rewards/lazada-credit-card/
# [29/105] Scraping: https://www.citibank.com.sg/credit-cards/privileges-programs/credit-card-petrol-savings/
# [30/105] Scraping: https://www.citibank.com.sg/credit-cards/cashback/citi-cash-back-card/
# [31/105] Scraping: https://www.citibank.com.sg/credit-cards/cashback/smrt-credit-card/
# [32/105] Scraping: https://www.citibank.com.sg/credit-cards/travel/premiermiles-card/
# [33/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/travelling-overseas/
# [34/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/change-and-update-details/
# [35/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/
# [36/105] Scraping: https://www.citibank.com.sg/wealth-management/investments/investment-products/fixed-income-securities/
# [37/105] Scraping: https://www.citibank.com.sg/wealth-management/investments/investment-products/foreign-exchange/
# [38/105] Scraping: https://www.citibank.com.sg/wealth-management/investments/investment-products/brokerage/
# [39/105] Scraping: https://www.citibank.com.sg/gcb/insurance/expertsolution.htm
# [40/105] Scraping: https://www.citibank.com.sg/wealth-management/investments/investment-products/online-unit-trusts/
# [41/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/living-overseas/
# [42/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/citibank-global-transfers/
# [43/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/moving-to-singapore/
# [44/105] Scraping: https://www.citibank.com.sg/loans/mortgage/referral-program/
# [45/105] Scraping: https://www.citibank.com.sg/personal-banking/other-services/
# [46/105] Scraping: https://www.citibank.com.sg/wealth-management/investments/investment-products/premium-account/
# [47/105] Scraping: https://www.citibank.com.sg/credit-cards/other-services/pay-my-bills/
# [48/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/global-investment-opportunities/
# [49/105] Scraping: https://www.citibank.com.sg/personal-banking/referral-programme/
# [50/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/savings-account/citi-maxigain-savings-account/
# [51/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/studying-in-singapore/
# [52/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/mobile-banking/sms-pay/
# [53/105] Scraping: https://www.citibank.com.sg/credit-cards/privileges-programs/credit-card-petrol-savings/shell-promotions/
# [54/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/savings-account/citi-wealth-first-account/
# [55/105] Scraping: https://www.citibank.com.sg/credit-cards/travel/complimentary-travel-insurance/
# [56/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/settling-in-singapore/
# [57/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/savings-account/money-market-account/
# [58/105] Scraping: https://www.citibank.com.sg/wealth-management/investments/investment-products/
# [59/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/savings-account/citibank-tap-and-save-account/
# [60/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/savings-account/children-savings-account/
# [61/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/electronic-statements-and-advices/
# [62/105] Scraping: https://www.citibank.com.sg/wealth-management/investments/services-information/online-investment/
# [63/105] Scraping: https://www.citibank.com.sg/credit-cards/privileges-programs/credit-card-petrol-savings/esso-promotions/
# [64/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/foreign-currency-account/global-currency-account/
# [65/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/working-in-singapore/
# [66/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/fixed-deposit-account/
# [67/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/foreign-currency-account/usd-checking-account/
# [68/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/savings-account/citibank-step-up-account/
# [69/105] Scraping: https://www.citibank.com.sg/wealth-management/investments/investment-products/regular-savings-plan/
# [70/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/savings-account/citibank-interest-plus-savings-account/
# [71/105] Scraping: https://www.citibank.com.sg/gcb/insurance/retirement-insurance-plan/index.html
# [72/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/foreign-currency-account/citi-access-account/
# [73/105] Scraping: https://www.citibank.com.sg/credit-cards/privileges-programs/online-shopping-shipping/
# [74/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/secure-banking/online-security-device/
# [75/105] Scraping: https://www.citibank.com.sg/gcb/insurance/legacy-planning/index.html
# [76/105] Scraping: https://www.citibank.com.sg/gcb/insurance/protection-insurance-plan/index.html
# [77/105] Scraping: https://www.citibank.com.sg/gcb/insurance/savings-insurance-plan/index.html
# [78/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/savings-account/citi-maxisave-account/
# [79/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/free-atm-withdrawls/
# [80/105] Scraping: https://www1.citibank.com.sg/credit-cards/other-services/click-to-pay
# [81/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/fixed-deposit-account/promotions/
# [82/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/
# [83/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/mobile-banking/add-payee/
# [84/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/secure-banking/pin-issuance-service/
# [85/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/mobile-banking/citi-alerts/
# [86/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/internet-banking/
# [87/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/online-payments/
# [88/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/mobile-banking/sms-alerts/
# [89/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/overseas-fund-transfers/
# [90/105] Scraping: https://www.citibank.com.sg/personal-banking/online-services/mobile-banking/
# [91/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/access-to-emergency-cash/
# [92/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/fixed-deposit-account/foreign-currency-time-account/
# [93/105] Scraping: https://www.citibank.com.sg/personal-banking/debit-card/multi-currency-e-wallet/
# [94/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/fixed-deposit-account/singapore-dollar-time-deposit/
# [95/105] Scraping: https://www.citibank.com.sg/personal-banking/global-banking/global-view-of-accounts/
# [96/105] Scraping: https://www.citibank.com.sg/personal-banking/deposits/foreign-currency-account/
# [97/105] Scraping: https://www.citibank.com.sg/personal-banking/other-services/citi-at-work/
# [98/105] Scraping: https://www1.citibank.com.sg/credit-cards/other-services/overseas-usage
# [99/105] Scraping: https://www.citibank.com.sg/loans/mortgage/learn-and-help/what-to-note-on-refinancing-your-mortgage-loan/
# [100/105] Scraping: https://www1.citibank.com.sg/loans/mortgage/learn-and-help/using-a-deposit-account-to-offset-mortgage-interest-rates
# [101/105] Scraping: https://www.citibank.com.sg/loans/mortgage/learn-and-help/what-is-ipa-and-how-will-it-help-your-mortgage-journey/
# [102/105] Scraping: https://www.citibank.com.sg/wealth-management/investments/portfolio-finance/
# [103/105] Scraping: https://www.citibank.com.sg/loans/mortgage/mortgage-faq
# [104/105] Scraping: https://www.citibank.com.sg/loans/mortgage/learn-and-help/points-to-note-prior-buying-your-new-home/
# [105/105] Scraping: https://www1.citibank.com.sg/loans/mortgage/learn-and-help/how-to-refinance-home-loan
# Scraping complete. Data saved to 'citibank_personal_banking_data.csv'.
